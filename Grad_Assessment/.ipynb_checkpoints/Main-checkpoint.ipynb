# %%
from Data_Preprocessing import *
from CRF_model import *
import numpy as np
from tensorflow import math
import tensorflow as tf

# %%
#Input: the filepath to one of en_ewt-ud-train.conllu, en_ewt-ud-test.conllu, or en_ewt-ud-dev.conllu
#Output: 1, x_final: a list containing each tokenized sentence within our file. 
#        2, x_lemmas_final: a list containing the lemma forms of each token within our tokenized sentences
#        3, y_final a list containing the POS tags that correspond to each token within our tokenized sentences
#        4, label_IDs: a dict containing every possible POS tag in our file alongside an integer ID for each one 
#        5, word_IDs: a dict containing every possible word token in our file alongside an integer ID for each one
       
def create_data(filepath, lines = None):
    
    
    
        
    
    with open(filepath, 'r', encoding='UTF-8') as f:
        x_toadd = []
        x_lemmas_toadd = []
        y_toadd = []
        x_final = []
        x_lemmas_final = []
        y_final = []
        label_IDs = {}
        word_IDs = {}
        
        limit = -1
        
        if lines is not None:
            limit = lines
        else:
            limit = sum(1 for line in f) + 1
        
        for line in f:
                       
            conllu = line.split()
            #case: end of sentence reached
            if len(conllu) == 0:
                
                #filters out one-word sentences such as links to websites
                if len(x_toadd) == 1:
                    x_toadd = []
                    x_lemmas_toadd = []
                    y_toadd = []  
                    continue
                    
                x_final.append(x_toadd)
                x_lemmas_final.append(x_lemmas_toadd)
                y_final.append(y_toadd)
                x_toadd = []
                x_lemmas_toadd = []
                y_toadd = []  
                
                limit -= 1
                if limit == 0:
                    break
                
                
                
            elif conllu[0].isnumeric():
                word = conllu[1]
#                 XPOS = conllu[4]
#                 extra_tags = conllu[5].split('|')
                label = conllu[3]
                lemma = conllu[2]
    
                if label not in label_IDs.keys():
                    label_IDs[label] = len(label_IDs)
                
                if word not in word_IDs.keys():
                    word_IDs[word] = len(word_IDs)
                    
                x_toadd.append(word)
                x_lemmas_toadd.append(lemma)
                y_toadd.append(label)
                
                
                    
                              
    return x_final, x_lemmas_final, y_final, label_IDs, word_IDs

# %%
x_sentences, x_lemmas, y_sentences, label_IDs, word_IDs = create_data("UD_English-EWT/en_ewt-ud-train.conllu", 10)

# %%
label_IDs['BOS'] = len(label_IDs)
label_IDs['EOS'] = len(label_IDs)
word_IDs['OOV'] = len(word_IDs)

# %%
datum = Data_Preprocessing(x_data = x_sentences[:10], y_data = y_sentences[:10], x_lemmas = x_lemmas[:10], x_vocab = list(word_IDs.keys()), labels = list(label_IDs.keys()), label_dict = label_IDs)

# %%
x_feats, y_feats = datum.generate_features()
# Out:
# Now generating x...
# Now generating y...

# %%
x_feats_np = np.asarray(x_feats, dtype=object)

# %%
crf = CRF_model(x_feats = x_feats_np, y_feats = y_feats, label_dict = label_IDs)

# %%
crf.train()
# Out:
# [[ 4.78819328e+25  6.86153720e+10  4.07080029e+24  4.64895312e+25
#   -4.21630185e+19 -8.45965542e+20 -2.19709390e+28 -3.52223732e+18
#    3.05576048e+15 -1.50903999e+05 -1.71893162e+27  5.32514567e+10
#    1.39348708e-01  5.75664538e+32  8.81475066e+16 -5.16174785e+22]
#   -1.09971624e-30 -1.18351049e-03 -9.26822482e-10  3.43804716e-04
#   -5.43152665e-15 -1.12137387e-06 -7.64890593e+05 -5.41984346e-03]
#  [-5.83086531e+16 -8.29017698e+01 -1.72945439e+05 -1.04801869e+15
#   -5.26963606e+11 -3.85741741e+09 -1.15610826e+14 -3.01740322e+04
#   -9.65004146e+06 -5.38106814e+01 -6.20922067e+09 -5.26265364e+07
#    4.00096436e+06 -2.90135630e+17 -4.15629241e+02 -6.79481061e+08]
#  [-4.77733527e+15 -8.60505148e+07 -7.04319352e+10 -4.38758598e+14
#   -5.63925337e+10 -1.72197407e+10 -1.17606613e+16 -5.15466992e+04
#   -1.72253988e+07 -1.65879351e-06 -4.07343210e+14 -6.02689378e+05
#   -6.55003953e-11  2.21361431e+19 -1.80035447e+05 -3.22832239e+12]
#  [-2.10087817e+04 -2.14926617e+01 -1.02852254e-13 -6.94187125e+02
#   -2.28888543e+02 -1.16466063e-02 -1.28374434e+03 -8.92471889e-15
#   -5.22830919e-03 -4.50735995e-57 -1.18037591e-02 -5.25832659e-06
#   -2.25368851e-02 -1.63349081e+09  2.29200579e-09 -6.07672350e+00]
#  [-1.14307262e-13 -5.67741126e-17 -1.20286763e+03 -2.60065058e-12
#   -1.00725092e-09 -6.41159055e-06 -6.13343685e-04 -2.05031873e-08
#   -1.48757730e-22 -1.45006928e-10 -4.21688343e+01 -1.90149622e-07
#   -7.71622335e-13 -1.71920196e-16 -2.31858392e+00  2.70038682e-11]]
# -6.0767234980501055
# (16, 16)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-08232b4df236> in <module>
# ----> 1 crf.train()
#
# ~\Documents\GitHub\NLP-Grad-Assessment\Grad_Assessment\CRF_model.py in train(self)
#      89         #adadelta = tf.keras.optimizers.Adadelta(learning_rate = 0.001, rho = 0.95, epsilon = 1e-07, name = 'Adadelta')
#      90
# ---> 91         lamb_final = optimize.fmin_l_bfgs_b(l, lamb_2)
#      92
#      93         #adadelta_run = adadelta.minimize(l, var_list = [lamb_final])
#
# ~\anaconda3\envs\tf3\lib\site-packages\scipy\optimize\lbfgsb.py in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     197
#     198     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
# --> 199                            **opts)
#     200     d = {'grad': res['jac'],
#     201          'task': res['message'],
#
# ~\anaconda3\envs\tf3\lib\site-packages\scipy\optimize\lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     343             # until the completion of the current minimization iteration.
#     344             # Overwrite f and g:
# --> 345             f, g = func_and_grad(x)
#     346         elif task_str.startswith(b'NEW_X'):
#     347             # new iteration
#
# ~\anaconda3\envs\tf3\lib\site-packages\scipy\optimize\lbfgsb.py in func_and_grad(x)
#     293     else:
#     294         def func_and_grad(x):
# --> 295             f = fun(x, *args)
#     296             g = jac(x, *args)
#     297             return f, g
#
# ~\anaconda3\envs\tf3\lib\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     325     def function_wrapper(*wrapper_args):
#     326         ncalls[0] += 1
# --> 327         return function(*(wrapper_args + args))
#     328
#     329     return ncalls, function_wrapper
#
# ~\anaconda3\envs\tf3\lib\site-packages\scipy\optimize\optimize.py in __call__(self, x, *args)
#      63     def __call__(self, x, *args):
#      64         self.x = numpy.asarray(x).copy()
# ---> 65         fg = self.fun(x, *args)
#      66         self.jac = fg[1]
#      67         return fg[0]
#
# ~\Documents\GitHub\NLP-Grad-Assessment\Grad_Assessment\CRF_model.py in <lambda>(lamb)
#      86
#      87         lamb_2 = np.random.randn(self.x[0].shape[3])
# ---> 88         l = lambda lamb: self.log_likelihood(lamb)
#      89         #adadelta = tf.keras.optimizers.Adadelta(learning_rate = 0.001, rho = 0.95, epsilon = 1e-07, name = 'Adadelta')
#      90
#
# ~\Documents\GitHub\NLP-Grad-Assessment\Grad_Assessment\CRF_model.py in log_likelihood(self, lamb)
#      76             print(Z[BOS_ID][EOS_ID])
#      77             print(Z.shape)
# ---> 78             print(math.log(Z[BOS_ID][EOS_ID]))
#      79             likelihood += (lamb_sum - math.log(Z[BOS_ID][EOS_ID]))
#      80
#
# ValueError: math domain error
